# %%
from Run.load_agent import load_agent
from Agents.YourAgent import YourAgent
from Run.run_episode import run_episode
from pettingzoo.classic import connect_four_v3
from Run.run_N_episodes import run_N_episodes
from Agents.RandomAgent import RandomAgent
from Agents.QLearnerAgent import QLearner
from Run.test_agent import test_agent
from Run.load_agent import load_agent
from Run.load_deep_agent import load_deep_agent
from Agents.AlphaBetaAgent import AlphaBetaAgent
import numpy
from tqdm import tqdm

# %%
env = connect_four_v3.env(render_mode='rgb_array')
env.reset()

# %%
possible_action = {0,1,2,3,4,5,6}
agent_1 = QLearner(possible_action, 
                env.observation_space)
agent_2 = QLearner(possible_action, 
                env.observation_space)
# agents = [agent_1,agent_2]
# run_N_episodes(env, agents, N_episodes=1000)

# %%
agent_3 = RandomAgent(env, possible_action, env.observation_space)

# %%
path = r'C:\Users\User\Documents\3A\RL\Projet\RL_Connect4\SavedAgents\qlearner_values_2.json'
agent_4 = load_agent(path, env)
print(len(agent_4.q_values))
# Out:
# Started Reading JSON file
# Converting JSON encoded data into Numpy array
# 975679

# %%
agent_5 = load_deep_agent(path, env)
# Out:
# Started Reading JSON file
# Converting JSON encoded data into Numpy array
# init

# %%
agent_6 = AlphaBetaAgent(possible_action, env.observation_space)

# %%
agent_7 = YourAgent()

# %%
test = test_agent(env,[agent_1, agent_3], 100)
print(test[0])
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 38.17it/s]
# {'player_0': 61, 'player_1': 39, 'equal': 0}
# {'player_0': 61, 'player_1': 39, 'equal': 0}

# %%
env = connect_four_v3.env(render_mode='rgb_array')
env.reset()
run_episode(env, [agent_3, agent_7], display=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21088/2431764437.py in <module>
#       1 env = connect_four_v3.env(render_mode='rgb_array')
#       2 env.reset()
# ----> 3 run_episode(env, [agent_3, agent_7], display=True)
#
# c:\Users\User\Documents\3A\RL\Projet\RL_Connect4\Run\run_episode.py in run_episode(env, agents, display)
#      29         action = agents[1].get_action(env,observation)
#      30         if not(termination or truncation):
# ---> 31             env.step(action)
#      32         next_observation, reward, termination, truncation, _ = env.last()
#      33         reward = env.rewards.get(agent_ids[1])
#
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\pettingzoo\utils\wrappers\order_enforcing.py in step(self, action)
#      73         else:
#      74             self._has_updated = True
# ...
